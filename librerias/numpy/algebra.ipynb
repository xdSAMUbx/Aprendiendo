# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img = plt.imread("../numpy/imagen_prueba1.jpg")
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (899, 1599, 3)

# %%
img.ndim
# Out:
# 3

# %%
img[:,:,0]
# Out:
# array([[111, 111, 111, ..., 118, 119, 120],
#        [110, 110, 111, ..., 117, 117, 118],
#        [109, 110, 110, ..., 115, 115, 116],
#        ...,
#        [ 66,  66,  66, ..., 141, 133, 131],
#        [ 66,  66,  66, ..., 140, 132, 131],
#        [ 66,  66,  66, ..., 138, 130, 130]], dtype=uint8)
